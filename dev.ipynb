# %%
from services.canonicalizer import Canonicalizer

# %%
canon = Canonicalizer("config/tag_registry/general.yaml", "config/tag_registry/creatures.yaml")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0

# %%
canon.analyze("The coat hanger is way too fast and the ray tracing is broken.")
# Out:
# [{'phrase': 'ray tracing',
#   'tag': 'graphics',
#   'category': 'game',
#   'descriptor': 'broken',
#   'sentiment': 'negative',
#   'sentence': 'The coat hanger is way too fast and the ray tracing is broken.'},
#  {'phrase': 'coat hanger',
#   'tag': 'bacteria',
#   'category': 'creature',
#   'descriptor': 'way too fast',
#   'sentiment': 'negative',
#   'sentence': 'The coat hanger is way too fast and the ray tracing is broken.'}]
